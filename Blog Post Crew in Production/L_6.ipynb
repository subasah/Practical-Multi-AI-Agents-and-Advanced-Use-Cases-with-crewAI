# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 213 packages in 1.79s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# openai     ------------------------------     0 B/585.03 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# mpmath     ------------------------------     0 B/523.63 KiB
# openai     ------------------------------     0 B/585.03 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# huggingface-hub ------------------------------     0 B/458.00 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# openai     ------------------------------     0 B/585.03 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# pydantic   ------------------------------     0 B/432.27 KiB
# huggingface-hub ------------------------------     0 B/458.00 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# openai     ------------------------------     0 B/585.03 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# prompt-toolkit ------------------------------     0 B/378.73 KiB
# pydantic   ------------------------------     0 B/432.27 KiB
# huggingface-hub ------------------------------     0 B/458.00 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# openai     ------------------------------     0 B/585.03 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# prompt-toolkit ------------------------------     0 B/378.73 KiB
# pydantic   ------------------------------     0 B/432.27 KiB
# huggingface-hub ------------------------------     0 B/458.00 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# openai     ------------------------------     0 B/585.03 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------ 14.91 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# prompt-toolkit ------------------------------     0 B/378.73 KiB
# pydantic   ------------------------------     0 B/432.27 KiB
# huggingface-hub ------------------------------     0 B/458.00 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# openai     ------------------------------     0 B/585.03 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------ 14.88 KiB/1.50 MiB
# kubernetes ------------------------------ 14.91 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# prompt-toolkit ------------------------------     0 B/378.73 KiB
# pydantic   ------------------------------     0 B/432.27 KiB
# huggingface-hub ------------------------------     0 B/458.00 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# openai     ------------------------------     0 B/585.03 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# jedi       ------------------------------ 14.88 KiB/1.50 MiB
# kubernetes ------------------------------ 14.91 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# prompt-toolkit ------------------------------     0 B/378.73 KiB
# pydantic   ------------------------------     0 B/432.27 KiB
# huggingface-hub ------------------------------     0 B/458.00 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# openai     ------------------------------ 14.89 KiB/585.03 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# jedi       ------------------------------ 14.88 KiB/1.50 MiB
# kubernetes ------------------------------ 14.91 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# prompt-toolkit ------------------------------     0 B/378.73 KiB
# pydantic   ------------------------------     0 B/432.27 KiB
# huggingface-hub ------------------------------     0 B/458.00 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# openai     ------------------------------ 14.89 KiB/585.03 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# jedi       ------------------------------ 14.88 KiB/1.50 MiB
# kubernetes ------------------------------ 14.91 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# prompt-toolkit ------------------------------     0 B/378.73 KiB
# pydantic   ------------------------------     0 B/432.27 KiB
# huggingface-hub ------------------------------ 14.88 KiB/458.00 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# openai     ------------------------------ 14.89 KiB/585.03 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# jedi       ------------------------------ 14.88 KiB/1.50 MiB
# kubernetes ------------------------------ 14.91 KiB/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# langsmith  ------------------------------ 16.00 KiB/343.61 KiB
# prompt-toolkit ------------------------------ 30.77 KiB/378.73 KiB
# rpds-py    ------------------------------ 16.00 KiB/380.31 KiB
# langchain-core ------------------------------ 30.88 KiB/410.26 KiB
# pydantic   ------------------------------ 30.88 KiB/432.27 KiB
# watchfiles ------------------------------ 30.91 KiB/441.97 KiB
# httptools  ------------------------------ 30.91 KiB/449.01 KiB
# cffi       ------------------------------ 16.00 KiB/456.29 KiB
# huggingface-hub ------------------------------ 46.88 KiB/458.00 KiB
# pytz       ------------------------------ 16.00 KiB/496.10 KiB
# mpmath     ------------------------------ 63.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 14.88 KiB/548.26 KiB
# openai     ------------------------------ 30.89 KiB/585.03 KiB
# greenlet   ------------------------------ 15.26 KiB/588.29 KiB
# chromadb   ------------------------------ 14.06 KiB/613.62 KiB
# pyvis      ------------------------------ 30.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 16.00 KiB/745.07 KiB
# regex      ------------------------------ 29.10 KiB/774.15 KiB
# ipython    ------------------------------ 16.00 KiB/807.35 KiB
# langchain  ------------------------------ 30.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 30.88 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# langsmith  ------------------------------ 16.00 KiB/343.61 KiB
# prompt-toolkit ------------------------------ 46.77 KiB/378.73 KiB
# rpds-py    ------------------------------ 174.02 KiB/380.31 KiB
# langchain-core ------------------------------ 46.88 KiB/410.26 KiB
# pydantic   ------------------------------ 62.88 KiB/432.27 KiB
# watchfiles ------------------------------ 190.91 KiB/441.97 KiB
# httptools  ------------------------------ 158.91 KiB/449.01 KiB
# cffi       ------------------------------ 174.56 KiB/456.29 KiB
# huggingface-hub ------------------------------ 62.88 KiB/458.00 KiB
# pytz       ------------------------------ 32.00 KiB/496.10 KiB
# mpmath     ------------------------------ 143.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 30.88 KiB/548.26 KiB
# openai     ------------------------------ 46.89 KiB/585.03 KiB
# greenlet   ------------------------------ 31.15 KiB/588.29 KiB
# chromadb   ------------------------------ 30.91 KiB/613.62 KiB
# pyvis      ------------------------------ 174.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 16.00 KiB/745.07 KiB
# regex      ------------------------------ 142.07 KiB/774.15 KiB
# ipython    ------------------------------ 16.00 KiB/807.35 KiB
# langchain  ------------------------------ 30.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 158.88 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# langsmith  ------------------------------ 96.00 KiB/343.61 KiB
# prompt-toolkit ------------------------------ 91.37 KiB/378.73 KiB
# rpds-py    ------------------------------ 254.02 KiB/380.31 KiB
# langchain-core ------------------------------ 62.88 KiB/410.26 KiB
# pydantic   ------------------------------ 154.96 KiB/432.27 KiB
# watchfiles ------------------------------ 270.09 KiB/441.97 KiB
# httptools  ------------------------------ 258.66 KiB/449.01 KiB
# cffi       ------------------------------ 254.45 KiB/456.29 KiB
# huggingface-hub ------------------------------ 225.03 KiB/458.00 KiB
# pytz       ------------------------------ 48.00 KiB/496.10 KiB
# mpmath     ------------------------------ 223.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 46.88 KiB/548.26 KiB
# openai     ------------------------------ 61.31 KiB/585.03 KiB
# greenlet   ------------------------------ 48.62 KiB/588.29 KiB
# chromadb   ------------------------------ 62.91 KiB/613.62 KiB
# pyvis      ------------------------------ 238.73 KiB/738.32 KiB
# pyyaml     ------------------------------ 255.95 KiB/745.07 KiB
# regex      ------------------------------ 221.96 KiB/774.15 KiB
# ipython    ------------------------------ 108.48 KiB/807.35 KiB
# langchain  ------------------------------ 46.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 238.88 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/206)
# langsmith  ------------------------------ 287.89 KiB/343.61 KiB
# prompt-toolkit ------------------------------ 91.37 KiB/378.73 KiB
# rpds-py    ------------------------------ 334.02 KiB/380.31 KiB
# langchain-core ------------------------------ 78.88 KiB/410.26 KiB
# pydantic   ------------------------------ 202.96 KiB/432.27 KiB
# watchfiles ------------------------------ 350.09 KiB/441.97 KiB
# httptools  ------------------------------ 326.83 KiB/449.01 KiB
# cffi       ------------------------------ 302.34 KiB/456.29 KiB
# huggingface-hub ------------------------------ 241.03 KiB/458.00 KiB
# pytz       ------------------------------ 48.00 KiB/496.10 KiB
# mpmath     ------------------------------ 303.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 46.88 KiB/548.26 KiB
# openai     ------------------------------ 77.31 KiB/585.03 KiB
# greenlet   ------------------------------ 319.46 KiB/588.29 KiB
# chromadb   ------------------------------ 78.91 KiB/613.62 KiB
# pyvis      ------------------------------ 318.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 335.95 KiB/745.07 KiB
# regex      ------------------------------ 286.07 KiB/774.15 KiB
# ipython    ------------------------------ 204.48 KiB/807.35 KiB
# langchain  ------------------------------ 46.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 318.88 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# langsmith  ------------------------------ 336.00 KiB/343.61 KiB
# prompt-toolkit ------------------------------ 107.37 KiB/378.73 KiB
# langchain-core ------------------------------ 109.58 KiB/410.26 KiB
# pydantic   ------------------------------ 250.85 KiB/432.27 KiB
# watchfiles ------------------------------ 398.09 KiB/441.97 KiB
# httptools  ------------------------------ 390.01 KiB/449.01 KiB
# cffi       ------------------------------ 334.56 KiB/456.29 KiB
# huggingface-hub ------------------------------ 314.62 KiB/458.00 KiB
# pytz       ------------------------------ 63.49 KiB/496.10 KiB
# mpmath     ------------------------------ 367.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 62.78 KiB/548.26 KiB
# openai     ------------------------------ 77.31 KiB/585.03 KiB
# greenlet   ------------------------------ 367.46 KiB/588.29 KiB
# chromadb   ------------------------------ 110.81 KiB/613.62 KiB
# pyvis      ------------------------------ 382.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 399.95 KiB/745.07 KiB
# regex      ------------------------------ 336.43 KiB/774.15 KiB
# ipython    ------------------------------ 252.48 KiB/807.35 KiB
# langchain  ------------------------------ 46.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 382.88 KiB/1.14 MiB
# pygments   ------------------------------ 319.69 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# langsmith  ------------------------------ 336.00 KiB/343.61 KiB
# prompt-toolkit ------------------------------ 114.19 KiB/378.73 KiB
# langchain-core ------------------------------ 125.58 KiB/410.26 KiB
# pydantic   ------------------------------ 266.85 KiB/432.27 KiB
# watchfiles ------------------------------ 414.09 KiB/441.97 KiB
# httptools  ------------------------------ 390.83 KiB/449.01 KiB
# cffi       ------------------------------ 366.56 KiB/456.29 KiB
# huggingface-hub ------------------------------ 330.62 KiB/458.00 KiB
# pytz       ------------------------------ 63.49 KiB/496.10 KiB
# mpmath     ------------------------------ 399.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 62.78 KiB/548.26 KiB
# openai     ------------------------------ 93.31 KiB/585.03 KiB
# greenlet   ------------------------------ 383.46 KiB/588.29 KiB
# chromadb   ------------------------------ 110.81 KiB/613.62 KiB
# pyvis      ------------------------------ 398.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 415.95 KiB/745.07 KiB
# regex      ------------------------------ 351.03 KiB/774.15 KiB
# ipython    ------------------------------ 268.48 KiB/807.35 KiB
# langchain  ------------------------------ 46.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 392.56 KiB/1.14 MiB
# pygments   ------------------------------ 335.69 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# tzdata     ------------------------------ 9.29 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 114.19 KiB/378.73 KiB
# langchain-core ------------------------------ 125.58 KiB/410.26 KiB
# pydantic   ------------------------------ 270.96 KiB/432.27 KiB
# watchfiles ------------------------------ 441.97 KiB/441.97 KiB
# httptools  ------------------------------ 422.83 KiB/449.01 KiB
# cffi       ------------------------------ 382.56 KiB/456.29 KiB
# huggingface-hub ------------------------------ 330.62 KiB/458.00 KiB
# pytz       ------------------------------ 111.39 KiB/496.10 KiB
# mpmath     ------------------------------ 415.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 62.78 KiB/548.26 KiB
# openai     ------------------------------ 93.31 KiB/585.03 KiB
# greenlet   ------------------------------ 415.46 KiB/588.29 KiB
# chromadb   ------------------------------ 350.09 KiB/613.62 KiB
# pyvis      ------------------------------ 430.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 431.95 KiB/745.07 KiB
# regex      ------------------------------ 383.03 KiB/774.15 KiB
# ipython    ------------------------------ 284.48 KiB/807.35 KiB
# langchain  ------------------------------ 46.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 424.46 KiB/1.14 MiB
# pygments   ------------------------------ 351.69 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# tzdata     ------------------------------ 9.29 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 130.19 KiB/378.73 KiB
# langchain-core ------------------------------ 125.58 KiB/410.26 KiB
# pydantic   ------------------------------ 286.96 KiB/432.27 KiB
# httptools  ------------------------------ 438.83 KiB/449.01 KiB
# cffi       ------------------------------ 382.56 KiB/456.29 KiB
# huggingface-hub ------------------------------ 330.62 KiB/458.00 KiB
# pytz       ------------------------------ 111.39 KiB/496.10 KiB
# mpmath     ------------------------------ 415.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 94.88 KiB/548.26 KiB
# openai     ------------------------------ 93.31 KiB/585.03 KiB
# greenlet   ------------------------------ 415.46 KiB/588.29 KiB
# chromadb   ------------------------------ 350.09 KiB/613.62 KiB
# pyvis      ------------------------------ 445.92 KiB/738.32 KiB
# pyyaml     ------------------------------ 447.95 KiB/745.07 KiB
# regex      ------------------------------ 398.07 KiB/774.15 KiB
# ipython    ------------------------------ 300.48 KiB/807.35 KiB
# langchain  ------------------------------ 46.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 440.46 KiB/1.14 MiB
# pygments   ------------------------------ 351.69 KiB/1.17 MiB
# jedi       ------------------------------ 187.02 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# yarl       ------------------------------     0 B/336.08 KiB
# jiter      ------------------------------ 16.00 KiB/337.45 KiB
# tzdata     ------------------------------ 9.29 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 130.19 KiB/378.73 KiB
# langchain-core ------------------------------ 158.88 KiB/410.26 KiB
# pydantic   ------------------------------ 302.96 KiB/432.27 KiB
# cffi       ------------------------------ 413.50 KiB/456.29 KiB
# huggingface-hub ------------------------------ 330.62 KiB/458.00 KiB
# pytz       ------------------------------ 111.39 KiB/496.10 KiB
# mpmath     ------------------------------ 431.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 110.88 KiB/548.26 KiB
# openai     ------------------------------ 109.31 KiB/585.03 KiB
# greenlet   ------------------------------ 447.46 KiB/588.29 KiB
# chromadb   ------------------------------ 350.09 KiB/613.62 KiB
# pyvis      ------------------------------ 462.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 479.95 KiB/745.07 KiB
# regex      ------------------------------ 420.15 KiB/774.15 KiB
# ipython    ------------------------------ 332.48 KiB/807.35 KiB
# langchain  ------------------------------ 46.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 456.56 KiB/1.14 MiB
# pygments   ------------------------------ 383.69 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# yarl       ------------------------------ 7.92 KiB/336.08 KiB
# jiter      ------------------------------ 16.00 KiB/337.45 KiB
# tzdata     ------------------------------ 23.37 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 130.19 KiB/378.73 KiB
# langchain-core ------------------------------ 158.88 KiB/410.26 KiB
# pydantic   ------------------------------ 302.96 KiB/432.27 KiB
# cffi       ------------------------------ 413.50 KiB/456.29 KiB
# huggingface-hub ------------------------------ 335.46 KiB/458.00 KiB
# pytz       ------------------------------ 111.39 KiB/496.10 KiB
# mpmath     ------------------------------ 447.22 KiB/523.63 KiB
# crewai-tools ------------------------------ 110.88 KiB/548.26 KiB
# openai     ------------------------------ 109.31 KiB/585.03 KiB
# greenlet   ------------------------------ 463.46 KiB/588.29 KiB
# chromadb   ------------------------------ 350.09 KiB/613.62 KiB
# pyvis      ------------------------------ 473.27 KiB/738.32 KiB
# pyyaml     ------------------------------ 495.95 KiB/745.07 KiB
# regex      ------------------------------ 420.15 KiB/774.15 KiB
# ipython    ------------------------------ 348.48 KiB/807.35 KiB
# langchain  ------------------------------ 46.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 472.56 KiB/1.14 MiB
# pygments   ------------------------------ 383.69 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# protobuf   ------------------------------ 32.00 KiB/312.18 KiB
# yarl       ------------------------------ 55.92 KiB/336.08 KiB
# jiter      ------------------------------ 81.31 KiB/337.45 KiB
# tzdata     ------------------------------ 23.37 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 171.37 KiB/378.73 KiB
# langchain-core ------------------------------ 174.88 KiB/410.26 KiB
# pydantic   ------------------------------ 334.96 KiB/432.27 KiB
# huggingface-hub ------------------------------ 351.46 KiB/458.00 KiB
# pytz       ------------------------------ 111.39 KiB/496.10 KiB
# mpmath     ------------------------------ 517.64 KiB/523.63 KiB
# crewai-tools ------------------------------ 476.25 KiB/548.26 KiB
# openai     ------------------------------ 141.20 KiB/585.03 KiB
# greenlet   ------------------------------ 527.35 KiB/588.29 KiB
# chromadb   ------------------------------ 395.64 KiB/613.62 KiB
# pyvis      ------------------------------ 526.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 559.95 KiB/745.07 KiB
# regex      ------------------------------ 462.45 KiB/774.15 KiB
# ipython    ------------------------------ 364.48 KiB/807.35 KiB
# langchain  ------------------------------ 62.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 520.56 KiB/1.14 MiB
# pygments   ------------------------------ 431.69 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# qdrant-client ------------------------------     0 B/299.49 KiB
# protobuf   ------------------------------ 63.10 KiB/312.18 KiB
# yarl       ------------------------------ 93.21 KiB/336.08 KiB
# jiter      ------------------------------ 113.31 KiB/337.45 KiB
# tzdata     ------------------------------ 23.37 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 187.37 KiB/378.73 KiB
# langchain-core ------------------------------ 190.77 KiB/410.26 KiB
# pydantic   ------------------------------ 391.70 KiB/432.27 KiB
# huggingface-hub ------------------------------ 351.46 KiB/458.00 KiB
# pytz       ------------------------------ 111.39 KiB/496.10 KiB
# mpmath     ------------------------------ 517.64 KiB/523.63 KiB
# crewai-tools ------------------------------ 476.25 KiB/548.26 KiB
# openai     ------------------------------ 157.20 KiB/585.03 KiB
# greenlet   ------------------------------ 528.24 KiB/588.29 KiB
# chromadb   ------------------------------ 395.64 KiB/613.62 KiB
# pyvis      ------------------------------ 558.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 582.30 KiB/745.07 KiB
# regex      ------------------------------ 508.69 KiB/774.15 KiB
# ipython    ------------------------------ 380.48 KiB/807.35 KiB
# langchain  ------------------------------ 62.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 568.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# qdrant-client ------------------------------ 14.88 KiB/299.49 KiB
# protobuf   ------------------------------ 79.10 KiB/312.18 KiB
# yarl       ------------------------------ 109.21 KiB/336.08 KiB
# jiter      ------------------------------ 129.31 KiB/337.45 KiB
# tzdata     ------------------------------ 23.37 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 187.37 KiB/378.73 KiB
# langchain-core ------------------------------ 198.06 KiB/410.26 KiB
# pydantic   ------------------------------ 398.96 KiB/432.27 KiB
# huggingface-hub ------------------------------ 367.46 KiB/458.00 KiB
# pytz       ------------------------------ 111.39 KiB/496.10 KiB
# crewai-tools ------------------------------ 476.25 KiB/548.26 KiB
# openai     ------------------------------ 157.20 KiB/585.03 KiB
# greenlet   ------------------------------ 544.24 KiB/588.29 KiB
# chromadb   ------------------------------ 395.64 KiB/613.62 KiB
# pyvis      ------------------------------ 574.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 598.30 KiB/745.07 KiB
# regex      ------------------------------ 524.69 KiB/774.15 KiB
# ipython    ------------------------------ 396.48 KiB/807.35 KiB
# langchain  ------------------------------ 62.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 584.56 KiB/1.14 MiB
# pygments   ------------------------------ 463.69 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# pypdf      ------------------------------     0 B/295.22 KiB
# qdrant-client ------------------------------ 30.88 KiB/299.49 KiB
# protobuf   ------------------------------ 111.10 KiB/312.18 KiB
# yarl       ------------------------------ 125.21 KiB/336.08 KiB
# jiter      ------------------------------ 161.31 KiB/337.45 KiB
# tzdata     ------------------------------ 23.37 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 203.37 KiB/378.73 KiB
# langchain-core ------------------------------ 250.33 KiB/410.26 KiB
# huggingface-hub ------------------------------ 383.46 KiB/458.00 KiB
# pytz       ------------------------------ 127.39 KiB/496.10 KiB
# crewai-tools ------------------------------ 492.25 KiB/548.26 KiB
# openai     ------------------------------ 173.20 KiB/585.03 KiB
# greenlet   ------------------------------ 544.24 KiB/588.29 KiB
# chromadb   ------------------------------ 414.09 KiB/613.62 KiB
# pyvis      ------------------------------ 606.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 623.95 KiB/745.07 KiB
# regex      ------------------------------ 542.07 KiB/774.15 KiB
# ipython    ------------------------------ 396.48 KiB/807.35 KiB
# langchain  ------------------------------ 78.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 610.16 KiB/1.14 MiB
# pygments   ------------------------------ 494.21 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/206)
# azure-search-documents ------------------------------ 14.90 KiB/291.76 KiB
# pypdf      ------------------------------ 48.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 78.88 KiB/299.49 KiB
# protobuf   ------------------------------ 159.10 KiB/312.18 KiB
# yarl       ------------------------------ 173.21 KiB/336.08 KiB
# jiter      ------------------------------ 209.31 KiB/337.45 KiB
# tzdata     ------------------------------ 79.28 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 267.37 KiB/378.73 KiB
# langchain-core ------------------------------ 302.88 KiB/410.26 KiB
# huggingface-hub ------------------------------ 415.46 KiB/458.00 KiB
# pytz       ------------------------------ 127.39 KiB/496.10 KiB
# crewai-tools ------------------------------ 492.25 KiB/548.26 KiB
# openai     ------------------------------ 205.31 KiB/585.03 KiB
# greenlet   ------------------------------ 560.13 KiB/588.29 KiB
# chromadb   ------------------------------ 430.09 KiB/613.62 KiB
# pyvis      ------------------------------ 654.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 661.59 KiB/745.07 KiB
# regex      ------------------------------ 590.07 KiB/774.15 KiB
# ipython    ------------------------------ 444.48 KiB/807.35 KiB
# langchain  ------------------------------ 78.88 KiB/988.00 KiB
# tiktoken   ------------------------------ 648.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# azure-search-documents ------------------------------ 46.90 KiB/291.76 KiB
# pypdf      ------------------------------ 128.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 126.88 KiB/299.49 KiB
# protobuf   ------------------------------ 223.10 KiB/312.18 KiB
# yarl       ------------------------------ 244.20 KiB/336.08 KiB
# jiter      ------------------------------ 273.31 KiB/337.45 KiB
# tzdata     ------------------------------ 79.28 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 303.37 KiB/378.73 KiB
# langchain-core ------------------------------ 350.88 KiB/410.26 KiB
# pytz       ------------------------------ 127.39 KiB/496.10 KiB
# crewai-tools ------------------------------ 524.25 KiB/548.26 KiB
# openai     ------------------------------ 246.67 KiB/585.03 KiB
# greenlet   ------------------------------ 577.77 KiB/588.29 KiB
# chromadb   ------------------------------ 462.09 KiB/613.62 KiB
# pyvis      ------------------------------ 716.75 KiB/738.32 KiB
# pyyaml     ------------------------------ 703.95 KiB/745.07 KiB
# regex      ------------------------------ 653.96 KiB/774.15 KiB
# ipython    ------------------------------ 476.48 KiB/807.35 KiB
# langchain  ------------------------------ 105.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 696.57 KiB/1.14 MiB
# pygments   ------------------------------ 591.59 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# azure-search-documents ------------------------------ 62.90 KiB/291.76 KiB
# pypdf      ------------------------------ 128.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 126.88 KiB/299.49 KiB
# protobuf   ------------------------------ 239.10 KiB/312.18 KiB
# yarl       ------------------------------ 253.21 KiB/336.08 KiB
# jiter      ------------------------------ 289.31 KiB/337.45 KiB
# tzdata     ------------------------------ 79.28 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 335.37 KiB/378.73 KiB
# langchain-core ------------------------------ 350.88 KiB/410.26 KiB
# pytz       ------------------------------ 143.49 KiB/496.10 KiB
# crewai-tools ------------------------------ 524.25 KiB/548.26 KiB
# openai     ------------------------------ 246.67 KiB/585.03 KiB
# greenlet   ------------------------------ 588.29 KiB/588.29 KiB
# chromadb   ------------------------------ 478.09 KiB/613.62 KiB
# pyvis      ------------------------------ 718.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 734.56 KiB/745.07 KiB
# regex      ------------------------------ 654.07 KiB/774.15 KiB
# ipython    ------------------------------ 476.48 KiB/807.35 KiB
# langchain  ------------------------------ 105.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 712.56 KiB/1.14 MiB
# pygments   ------------------------------ 607.59 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# googleapis-common-protos ------------------------------ 16.00 KiB/286.34 KiB
# azure-search-documents ------------------------------ 78.90 KiB/291.76 KiB
# pypdf      ------------------------------ 130.80 KiB/295.22 KiB
# qdrant-client ------------------------------ 138.54 KiB/299.49 KiB
# protobuf   ------------------------------ 255.10 KiB/312.18 KiB
# yarl       ------------------------------ 269.21 KiB/336.08 KiB
# jiter      ------------------------------ 305.31 KiB/337.45 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 335.37 KiB/378.73 KiB
# langchain-core ------------------------------ 350.88 KiB/410.26 KiB
# pytz       ------------------------------ 143.49 KiB/496.10 KiB
# crewai-tools ------------------------------ 524.25 KiB/548.26 KiB
# openai     ------------------------------ 246.67 KiB/585.03 KiB
# chromadb   ------------------------------ 478.09 KiB/613.62 KiB
# pyvis      ------------------------------ 734.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 734.92 KiB/745.07 KiB
# regex      ------------------------------ 686.07 KiB/774.15 KiB
# ipython    ------------------------------ 510.75 KiB/807.35 KiB
# langchain  ------------------------------ 121.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 743.91 KiB/1.14 MiB
# pygments   ------------------------------ 623.69 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# googleapis-common-protos ------------------------------ 16.00 KiB/286.34 KiB
# azure-search-documents ------------------------------ 78.90 KiB/291.76 KiB
# pypdf      ------------------------------ 162.80 KiB/295.22 KiB
# qdrant-client ------------------------------ 138.54 KiB/299.49 KiB
# protobuf   ------------------------------ 255.10 KiB/312.18 KiB
# yarl       ------------------------------ 285.11 KiB/336.08 KiB
# jiter      ------------------------------ 333.21 KiB/337.45 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 351.37 KiB/378.73 KiB
# langchain-core ------------------------------ 366.88 KiB/410.26 KiB
# pytz       ------------------------------ 143.49 KiB/496.10 KiB
# crewai-tools ------------------------------ 540.03 KiB/548.26 KiB
# openai     ------------------------------ 253.31 KiB/585.03 KiB
# chromadb   ------------------------------ 478.09 KiB/613.62 KiB
# pyyaml     ------------------------------ 735.95 KiB/745.07 KiB
# regex      ------------------------------ 702.07 KiB/774.15 KiB
# ipython    ------------------------------ 524.48 KiB/807.35 KiB
# langchain  ------------------------------ 121.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 759.91 KiB/1.14 MiB
# pygments   ------------------------------ 655.47 KiB/1.17 MiB
# jedi       ------------------------------ 260.79 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# bcrypt     ------------------------------     0 B/277.50 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/286.34 KiB
# azure-search-documents ------------------------------ 94.90 KiB/291.76 KiB
# pypdf      ------------------------------ 192.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 158.88 KiB/299.49 KiB
# protobuf   ------------------------------ 271.10 KiB/312.18 KiB
# yarl       ------------------------------ 317.11 KiB/336.08 KiB
# jiter      ------------------------------ 337.45 KiB/337.45 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 367.37 KiB/378.73 KiB
# langchain-core ------------------------------ 366.88 KiB/410.26 KiB
# pytz       ------------------------------ 143.49 KiB/496.10 KiB
# crewai-tools ------------------------------ 540.03 KiB/548.26 KiB
# openai     ------------------------------ 253.31 KiB/585.03 KiB
# chromadb   ------------------------------ 478.09 KiB/613.62 KiB
# regex      ------------------------------ 718.07 KiB/774.15 KiB
# ipython    ------------------------------ 564.38 KiB/807.35 KiB
# langchain  ------------------------------ 121.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 775.91 KiB/1.14 MiB
# pygments   ------------------------------ 655.47 KiB/1.17 MiB
# jedi       ------------------------------ 267.02 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# bcrypt     ------------------------------     0 B/277.50 KiB
# googleapis-common-protos ------------------------------ 32.00 KiB/286.34 KiB
# azure-search-documents ------------------------------ 94.90 KiB/291.76 KiB
# pypdf      ------------------------------ 192.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 158.88 KiB/299.49 KiB
# protobuf   ------------------------------ 271.10 KiB/312.18 KiB
# yarl       ------------------------------ 317.11 KiB/336.08 KiB
# jiter      ------------------------------ 337.45 KiB/337.45 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 367.37 KiB/378.73 KiB
# langchain-core ------------------------------ 382.88 KiB/410.26 KiB
# pytz       ------------------------------ 143.49 KiB/496.10 KiB
# openai     ------------------------------ 253.31 KiB/585.03 KiB
# chromadb   ------------------------------ 478.09 KiB/613.62 KiB
# regex      ------------------------------ 718.07 KiB/774.15 KiB
# ipython    ------------------------------ 564.38 KiB/807.35 KiB
# langchain  ------------------------------ 121.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 775.91 KiB/1.14 MiB
# pygments   ------------------------------ 687.69 KiB/1.17 MiB
# jedi       ------------------------------ 267.02 KiB/1.50 MiB
# aiohttp    ------------------------------ 748.99 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# frozenlist ------------------------------     0 B/268.43 KiB
# bcrypt     ------------------------------ 16.00 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 32.00 KiB/286.34 KiB
# azure-search-documents ------------------------------ 94.90 KiB/291.76 KiB
# pypdf      ------------------------------ 192.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 158.88 KiB/299.49 KiB
# protobuf   ------------------------------ 271.10 KiB/312.18 KiB
# yarl       ------------------------------ 317.11 KiB/336.08 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 367.37 KiB/378.73 KiB
# langchain-core ------------------------------ 382.88 KiB/410.26 KiB
# pytz       ------------------------------ 143.49 KiB/496.10 KiB
# openai     ------------------------------ 253.31 KiB/585.03 KiB
# chromadb   ------------------------------ 478.09 KiB/613.62 KiB
# regex      ------------------------------ 718.07 KiB/774.15 KiB
# ipython    ------------------------------ 580.38 KiB/807.35 KiB
# langchain  ------------------------------ 121.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 775.91 KiB/1.14 MiB
# pygments   ------------------------------ 687.69 KiB/1.17 MiB
# jedi       ------------------------------ 267.02 KiB/1.50 MiB
# aiohttp    ------------------------------ 748.99 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# cohere     ------------------------------     0 B/247.99 KiB
# crewai     ------------------------------     0 B/259.05 KiB
# frozenlist ------------------------------ 16.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 32.00 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 48.00 KiB/286.34 KiB
# azure-search-documents ------------------------------ 110.90 KiB/291.76 KiB
# pypdf      ------------------------------ 208.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 174.88 KiB/299.49 KiB
# protobuf   ------------------------------ 287.10 KiB/312.18 KiB
# yarl       ------------------------------ 317.21 KiB/336.08 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# langchain-core ------------------------------ 392.57 KiB/410.26 KiB
# pytz       ------------------------------ 159.49 KiB/496.10 KiB
# openai     ------------------------------ 269.31 KiB/585.03 KiB
# chromadb   ------------------------------ 478.09 KiB/613.62 KiB
# regex      ------------------------------ 734.07 KiB/774.15 KiB
# ipython    ------------------------------ 580.38 KiB/807.35 KiB
# langchain  ------------------------------ 137.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 776.56 KiB/1.14 MiB
# pygments   ------------------------------ 735.69 KiB/1.17 MiB
# jedi       ------------------------------ 267.02 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# openpyxl   ------------------------------     0 B/245.03 KiB
# cohere     ------------------------------     0 B/247.99 KiB
# crewai     ------------------------------     0 B/259.05 KiB
# frozenlist ------------------------------ 16.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 32.00 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 48.00 KiB/286.34 KiB
# azure-search-documents ------------------------------ 126.79 KiB/291.76 KiB
# pypdf      ------------------------------ 208.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 190.88 KiB/299.49 KiB
# protobuf   ------------------------------ 303.10 KiB/312.18 KiB
# yarl       ------------------------------ 317.21 KiB/336.08 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# langchain-core ------------------------------ 398.88 KiB/410.26 KiB
# pytz       ------------------------------ 159.49 KiB/496.10 KiB
# openai     ------------------------------ 269.31 KiB/585.03 KiB
# chromadb   ------------------------------ 494.09 KiB/613.62 KiB
# regex      ------------------------------ 750.07 KiB/774.15 KiB
# ipython    ------------------------------ 596.38 KiB/807.35 KiB
# langchain  ------------------------------ 137.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 792.56 KiB/1.14 MiB
# pygments   ------------------------------ 751.69 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# openpyxl   ------------------------------     0 B/245.03 KiB
# cohere     ------------------------------     0 B/247.99 KiB
# crewai     ------------------------------     0 B/259.05 KiB
# frozenlist ------------------------------ 16.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 32.00 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 48.00 KiB/286.34 KiB
# azure-search-documents ------------------------------ 126.79 KiB/291.76 KiB
# pypdf      ------------------------------ 208.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 190.88 KiB/299.49 KiB
# protobuf   ------------------------------ 303.10 KiB/312.18 KiB
# yarl       ------------------------------ 317.21 KiB/336.08 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# pytz       ------------------------------ 159.49 KiB/496.10 KiB
# openai     ------------------------------ 269.31 KiB/585.03 KiB
# chromadb   ------------------------------ 494.09 KiB/613.62 KiB
# regex      ------------------------------ 750.07 KiB/774.15 KiB
# ipython    ------------------------------ 596.38 KiB/807.35 KiB
# langchain  ------------------------------ 137.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 792.56 KiB/1.14 MiB
# pygments   ------------------------------ 751.69 KiB/1.17 MiB
# jedi       ------------------------------ 267.02 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# tomli      ------------------------------     0 B/230.50 KiB
# rich       ------------------------------ 14.91 KiB/236.74 KiB
# openpyxl   ------------------------------ 8.31 KiB/245.03 KiB
# cohere     ------------------------------ 48.00 KiB/247.99 KiB
# crewai     ------------------------------ 32.00 KiB/259.05 KiB
# frozenlist ------------------------------ 60.72 KiB/268.43 KiB
# bcrypt     ------------------------------ 77.15 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 60.31 KiB/286.34 KiB
# azure-search-documents ------------------------------ 142.79 KiB/291.76 KiB
# pypdf      ------------------------------ 240.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 222.88 KiB/299.49 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# yarl       ------------------------------ 336.08 KiB/336.08 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# pytz       ------------------------------ 159.49 KiB/496.10 KiB
# openai     ------------------------------ 269.31 KiB/585.03 KiB
# chromadb   ------------------------------ 494.09 KiB/613.62 KiB
# ipython    ------------------------------ 620.48 KiB/807.35 KiB
# langchain  ------------------------------ 137.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 820.37 KiB/1.14 MiB
# pygments   ------------------------------ 799.69 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# tomli      ------------------------------     0 B/230.50 KiB
# rich       ------------------------------ 14.91 KiB/236.74 KiB
# openpyxl   ------------------------------ 8.31 KiB/245.03 KiB
# cohere     ------------------------------ 48.00 KiB/247.99 KiB
# crewai     ------------------------------ 32.00 KiB/259.05 KiB
# frozenlist ------------------------------ 60.72 KiB/268.43 KiB
# bcrypt     ------------------------------ 77.15 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 60.31 KiB/286.34 KiB
# azure-search-documents ------------------------------ 142.79 KiB/291.76 KiB
# pypdf      ------------------------------ 240.00 KiB/295.22 KiB
# qdrant-client ------------------------------ 222.88 KiB/299.49 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# pytz       ------------------------------ 159.49 KiB/496.10 KiB
# openai     ------------------------------ 269.31 KiB/585.03 KiB
# chromadb   ------------------------------ 494.09 KiB/613.62 KiB
# ipython    ------------------------------ 620.48 KiB/807.35 KiB
# langchain  ------------------------------ 137.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 820.37 KiB/1.14 MiB
# pygments   ------------------------------ 799.69 KiB/1.17 MiB
# jedi       ------------------------------ 267.02 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# alembic    ------------------------------ 16.00 KiB/226.48 KiB
# propcache  ------------------------------ 8.02 KiB/227.05 KiB
# tomli      ------------------------------ 48.00 KiB/230.50 KiB
# rich       ------------------------------ 56.84 KiB/236.74 KiB
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# cohere     ------------------------------ 64.00 KiB/247.99 KiB
# crewai     ------------------------------ 64.00 KiB/259.05 KiB
# frozenlist ------------------------------ 108.72 KiB/268.43 KiB
# bcrypt     ------------------------------ 125.15 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 76.31 KiB/286.34 KiB
# azure-search-documents ------------------------------ 236.13 KiB/291.76 KiB
# pypdf      ------------------------------ 263.35 KiB/295.22 KiB
# qdrant-client ------------------------------ 238.88 KiB/299.49 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# tzdata     ------------------------------ 95.28 KiB/339.69 KiB
# pytz       ------------------------------ 175.49 KiB/496.10 KiB
# openai     ------------------------------ 275.66 KiB/585.03 KiB
# chromadb   ------------------------------ 526.09 KiB/613.62 KiB
# ipython    ------------------------------ 652.48 KiB/807.35 KiB
# langchain  ------------------------------ 137.42 KiB/988.00 KiB
# tiktoken   ------------------------------ 856.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/206)
# alembic    ------------------------------ 64.00 KiB/226.48 KiB
# propcache  ------------------------------ 56.02 KiB/227.05 KiB
# ...
# onnxruntime ------------------------------ 12.88 MiB/15.26 MiB
# numpy      ------------------------------ 7.39 MiB/15.67 MiB
# uv         ------------------------------ 12.64 MiB/15.85 MiB
# lancedb    ------------------------------ 12.78 MiB/31.40 MiB
# ⠸ Preparing packages... (199/206) 12.68 MiB/40.13 MiB
# pyright    ------------------------------ 3.05 MiB/5.51 MiB
# pandas     ------------------------------ 12.33 MiB/12.45 MiB
# onnxruntime ------------------------------ 14.04 MiB/15.26 MiB
# numpy      ------------------------------ 7.66 MiB/15.67 MiB
# uv         ------------------------------ 13.85 MiB/15.85 MiB
# lancedb    ------------------------------ 13.98 MiB/31.40 MiB
# ⠼ Preparing packages... (199/206) 13.92 MiB/40.13 MiB
# pyright    ------------------------------ 3.05 MiB/5.51 MiB
# pandas     ------------------------------ 12.34 MiB/12.45 MiB
# onnxruntime ------------------------------ 14.04 MiB/15.26 MiB
# numpy      ------------------------------ 7.85 MiB/15.67 MiB
# uv         ------------------------------ 14.00 MiB/15.85 MiB
# lancedb    ------------------------------ 14.06 MiB/31.40 MiB
# ⠼ Preparing packages... (199/206) 14.09 MiB/40.13 MiB
# pyright    ------------------------------ 3.05 MiB/5.51 MiB
# pandas     ------------------------------ 12.36 MiB/12.45 MiB
# onnxruntime ------------------------------ 14.04 MiB/15.26 MiB
# numpy      ------------------------------ 7.85 MiB/15.67 MiB
# uv         ------------------------------ 14.00 MiB/15.85 MiB
# lancedb    ------------------------------ 14.06 MiB/31.40 MiB
# ⠼ Preparing packages... (199/206) 14.09 MiB/40.13 MiB
# pyright    ------------------------------ 3.05 MiB/5.51 MiB
# pandas     ------------------------------ 12.37 MiB/12.45 MiB
# onnxruntime ------------------------------ 14.04 MiB/15.26 MiB
# numpy      ------------------------------ 7.85 MiB/15.67 MiB
# uv         ------------------------------ 14.00 MiB/15.85 MiB
# lancedb    ------------------------------ 14.06 MiB/31.40 MiB
# ⠼ Preparing packages... (199/206) 14.09 MiB/40.13 MiB
# pyright    ------------------------------ 3.05 MiB/5.51 MiB
# pandas     ------------------------------ 12.45 MiB/12.45 MiB
# onnxruntime ------------------------------ 14.30 MiB/15.26 MiB
# numpy      ------------------------------ 7.85 MiB/15.67 MiB
# uv         ------------------------------ 14.19 MiB/15.85 MiB
# lancedb    ------------------------------ 14.28 MiB/31.40 MiB
# ⠼ Preparing packages... (199/206) 14.09 MiB/40.13 MiB
# pyright    ------------------------------ 3.05 MiB/5.51 MiB
# onnxruntime ------------------------------ 14.30 MiB/15.26 MiB
# numpy      ------------------------------ 7.85 MiB/15.67 MiB
# uv         ------------------------------ 14.19 MiB/15.85 MiB
# lancedb    ------------------------------ 14.28 MiB/31.40 MiB
# ⠴ Preparing packages... (200/206) 14.09 MiB/40.13 MiB
# pyright    ------------------------------ 3.20 MiB/5.51 MiB
# onnxruntime ------------------------------ 14.99 MiB/15.26 MiB
# numpy      ------------------------------ 8.24 MiB/15.67 MiB
# uv         ------------------------------ 14.59 MiB/15.85 MiB
# lancedb    ------------------------------ 14.91 MiB/31.40 MiB
# ⠴ Preparing packages... (200/206) 14.09 MiB/40.13 MiB
# pyright    ------------------------------ 3.25 MiB/5.51 MiB
# numpy      ------------------------------ 10.86 MiB/15.67 MiB
# uv         ------------------------------ 14.59 MiB/15.85 MiB
# lancedb    ------------------------------ 15.81 MiB/31.40 MiB
# ⠴ Preparing packages... (200/206) 14.09 MiB/40.13 MiB
# pyright    ------------------------------ 3.25 MiB/5.51 MiB
# numpy      ------------------------------ 10.87 MiB/15.67 MiB
# uv         ------------------------------ 14.59 MiB/15.85 MiB
# lancedb    ------------------------------ 15.82 MiB/31.40 MiB
# ⠴ Preparing packages... (200/206) 14.09 MiB/40.13 MiB
# pyright    ------------------------------ 3.26 MiB/5.51 MiB
# numpy      ------------------------------ 11.67 MiB/15.67 MiB
# lancedb    ------------------------------ 16.52 MiB/31.40 MiB
# ⠴ Preparing packages... (200/206) 14.09 MiB/40.13 MiB
# pyright    ------------------------------ 3.26 MiB/5.51 MiB
# numpy      ------------------------------ 12.41 MiB/15.67 MiB
# lancedb    ------------------------------ 17.88 MiB/31.40 MiB
# ⠴ Preparing packages... (200/206) 14.09 MiB/40.13 MiB
# pyright    ------------------------------ 3.26 MiB/5.51 MiB
# numpy      ------------------------------ 14.28 MiB/15.67 MiB
# lancedb    ------------------------------ 19.83 MiB/31.40 MiB
# ⠦ Preparing packages... (202/206) 15.24 MiB/40.13 MiB
# pyright    ------------------------------ 3.26 MiB/5.51 MiB
# numpy      ------------------------------ 15.59 MiB/15.67 MiB
# lancedb    ------------------------------ 21.23 MiB/31.40 MiB
# ⠦ Preparing packages... (202/206) 17.11 MiB/40.13 MiB
# pyright    ------------------------------ 3.26 MiB/5.51 MiB
# lancedb    ------------------------------ 21.73 MiB/31.40 MiB
# ⠧ Preparing packages... (203/206) 18.47 MiB/40.13 MiB
# pyright    ------------------------------ 3.26 MiB/5.51 MiB
# lancedb    ------------------------------ 21.73 MiB/31.40 MiB
# ⠧ Preparing packages... (203/206) 18.47 MiB/40.13 MiB
# pyright    ------------------------------ 3.26 MiB/5.51 MiB
# lancedb    ------------------------------ 21.73 MiB/31.40 MiB
# ⠧ Preparing packages... (203/206) 18.50 MiB/40.13 MiB
# pyright    ------------------------------ 3.26 MiB/5.51 MiB
# lancedb    ------------------------------ 21.73 MiB/31.40 MiB
# ⠧ Preparing packages... (203/206) 18.52 MiB/40.13 MiB
# pyright    ------------------------------ 3.26 MiB/5.51 MiB
# lancedb    ------------------------------ 21.73 MiB/31.40 MiB
# ⠧ Preparing packages... (203/206) 18.53 MiB/40.13 MiB
# pyright    ------------------------------ 3.26 MiB/5.51 MiB
# lancedb    ------------------------------ 22.58 MiB/31.40 MiB
# ⠧ Preparing packages... (203/206) 19.68 MiB/40.13 MiB
# pyright    ------------------------------ 3.36 MiB/5.51 MiB
# lancedb    ------------------------------ 24.89 MiB/31.40 MiB
# ⠇ Preparing packages... (203/206) 19.97 MiB/40.13 MiB
# pyright    ------------------------------ 3.36 MiB/5.51 MiB
# lancedb    ------------------------------ 24.89 MiB/31.40 MiB
# ⠇ Preparing packages... (203/206) 20.93 MiB/40.13 MiB
# pyright    ------------------------------ 3.37 MiB/5.51 MiB
# lancedb    ------------------------------ 24.89 MiB/31.40 MiB
# ⠇ Preparing packages... (203/206) 20.93 MiB/40.13 MiB
# pyright    ------------------------------ 3.43 MiB/5.51 MiB
# lancedb    ------------------------------ 24.95 MiB/31.40 MiB
# ⠇ Preparing packages... (203/206) 20.93 MiB/40.13 MiB
# pyright    ------------------------------ 3.49 MiB/5.51 MiB
# lancedb    ------------------------------ 29.24 MiB/31.40 MiB
# ⠇ Preparing packages... (203/206) 20.93 MiB/40.13 MiB
# pyright    ------------------------------ 3.68 MiB/5.51 MiB
# lancedb    ------------------------------ 30.87 MiB/31.40 MiB
# ⠙ Preparing packages... (203/206) 20.93 MiB/40.13 MiB
# pyright    ------------------------------ 3.68 MiB/5.51 MiB
# lancedb    ------------------------------ 30.95 MiB/31.40 MiB
# ⠙ Preparing packages... (203/206) 20.93 MiB/40.13 MiB
# pyright    ------------------------------ 3.68 MiB/5.51 MiB
# lancedb    ------------------------------ 30.99 MiB/31.40 MiB
# ⠙ Preparing packages... (203/206) 20.93 MiB/40.13 MiB
# pyright    ------------------------------ 3.68 MiB/5.51 MiB
# lancedb    ------------------------------ 31.00 MiB/31.40 MiB
# ⠙ Preparing packages... (203/206) 20.93 MiB/40.13 MiB
# pyright    ------------------------------ 3.68 MiB/5.51 MiB
# lancedb    ------------------------------ 31.02 MiB/31.40 MiB
# ⠙ Preparing packages... (203/206) 20.93 MiB/40.13 MiB
# pyright    ------------------------------ 3.68 MiB/5.51 MiB
# ⠙ Preparing packages... (203/206) 21.43 MiB/40.13 MiB
# pyright    ------------------------------ 3.90 MiB/5.51 MiB
# ⠹ Preparing packages... (204/206) 21.43 MiB/40.13 MiB
# pyright    ------------------------------ 4.08 MiB/5.51 MiB
# ⠹ Preparing packages... (204/206) 21.43 MiB/40.13 MiB
# pyright    ------------------------------ 4.08 MiB/5.51 MiB
# ⠹ Preparing packages... (204/206) 21.48 MiB/40.13 MiB
# pyright    ------------------------------ 4.08 MiB/5.51 MiB
# ⠹ Preparing packages... (204/206) 21.49 MiB/40.13 MiB
# pyright    ------------------------------ 4.09 MiB/5.51 MiB
# ⠹ Preparing packages... (204/206) 22.24 MiB/40.13 MiB
# pyright    ------------------------------ 4.26 MiB/5.51 MiB
# ⠸ Preparing packages... (204/206) 22.24 MiB/40.13 MiB
# pyright    ------------------------------ 4.46 MiB/5.51 MiB
# ⠸ Preparing packages... (204/206) 22.59 MiB/40.13 MiB
# pyright    ------------------------------ 4.46 MiB/5.51 MiB
# ⠸ Preparing packages... (204/206) 22.63 MiB/40.13 MiB
# pyright    ------------------------------ 4.46 MiB/5.51 MiB
# ⠸ Preparing packages... (204/206) 22.65 MiB/40.13 MiB
# pyright    ------------------------------ 4.46 MiB/5.51 MiB
# ⠸ Preparing packages... (204/206) 22.67 MiB/40.13 MiB
# pyright    ------------------------------ 4.46 MiB/5.51 MiB
# ⠼ Preparing packages... (204/206) 22.68 MiB/40.13 MiB
# pyright    ------------------------------ 4.46 MiB/5.51 MiB
# ⠼ Preparing packages... (204/206) 23.23 MiB/40.13 MiB
# pyright    ------------------------------ 4.46 MiB/5.51 MiB
# ⠼ Preparing packages... (204/206) 23.96 MiB/40.13 MiB
# pyright    ------------------------------ 4.47 MiB/5.51 MiB
# ⠼ Preparing packages... (204/206) 26.19 MiB/40.13 MiB
# pyright    ------------------------------ 4.55 MiB/5.51 MiB
# ⠴ Preparing packages... (204/206) 26.19 MiB/40.13 MiB
# pyright    ------------------------------ 4.65 MiB/5.51 MiB
# ⠴ Preparing packages... (204/206) 26.66 MiB/40.13 MiB
# pyright    ------------------------------ 4.65 MiB/5.51 MiB
# ⠴ Preparing packages... (204/206) 26.71 MiB/40.13 MiB
# pyright    ------------------------------ 4.65 MiB/5.51 MiB
# ⠴ Preparing packages... (204/206) 26.73 MiB/40.13 MiB
# pyright    ------------------------------ 4.65 MiB/5.51 MiB
# ⠴ Preparing packages... (204/206) 26.74 MiB/40.13 MiB
# pyright    ------------------------------ 4.65 MiB/5.51 MiB
# ⠦ Preparing packages... (204/206) 27.63 MiB/40.13 MiB
# pyright    ------------------------------ 4.67 MiB/5.51 MiB
# ⠦ Preparing packages... (204/206) 32.48 MiB/40.13 MiB
# pyright    ------------------------------ 4.67 MiB/5.51 MiB
# ⠦ Preparing packages... (204/206) 37.53 MiB/40.13 MiB
# ⠦ Preparing packages... (204/206) 38.49 MiB/40.13 MiB
# Prepared 206 packages in 6.59s
# Installed 206 packages in 270ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.11.14
#  + aiosignal==1.3.2
#  + alembic==1.15.2
#  + annotated-types==0.7.0
#  + anyio==4.9.0
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==3.0.0
#  + attrs==25.3.0
#  + auth0-python==4.8.1
#  + azure-common==1.1.28
#  + azure-core==1.32.0
#  + azure-search-documents==11.5.2
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + beautifulsoup4==4.13.3
#  + blinker==1.9.0
#  + build==1.2.2.post1
#  + cachetools==5.5.2
#  + certifi==2025.1.31
#  + cffi==1.17.1
#  + charset-normalizer==3.4.1
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.1.8
#  + cohere==5.14.0
#  + coloredlogs==15.0.1
#  + crewai==0.108.0
#  + crewai-tools==0.38.1
#  + cryptography==44.0.2
#  + dataclasses-json==0.6.7
#  + decorator==5.2.1
#  + deprecated==1.2.18
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + durationpy==0.9
#  + embedchain==0.1.128
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.115.12
#  + fastavro==1.10.0
#  + filelock==3.18.0
#  + flatbuffers==25.2.10
#  + frozenlist==1.5.0
#  + fsspec==2025.3.1
#  + google-auth==2.38.0
#  + googleapis-common-protos==1.69.2
#  + gptcache==0.1.44
#  + greenlet==3.1.1
#  + grpcio==1.71.0
#  + grpcio-tools==1.71.0
#  + h11==0.14.0
#  + h2==4.2.0
#  + hpack==4.1.0
#  + httpcore==1.0.7
#  + httptools==0.6.4
#  + httpx==0.27.2
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.29.3
#  + humanfriendly==10.0
#  + hyperframe==6.1.0
#  + idna==3.10
#  + importlib-metadata==8.6.1
#  + importlib-resources==6.5.2
#  + instructor==1.7.8
#  + ipython==8.34.0
#  + isodate==0.7.2
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.8.2
#  + json-repair==0.40.0
#  + json5==0.10.0
#  + jsonpatch==1.33
#  + jsonpickle==4.0.5
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2024.10.1
#  + kubernetes==32.0.1
#  + lancedb==0.21.2
#  + langchain==0.3.21
#  + langchain-cohere==0.3.5
#  + langchain-community==0.3.20
#  + langchain-core==0.3.49
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.7
#  + langsmith==0.3.19
#  + litellm==1.60.2
#  + mako==1.3.9
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.26.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.81
#  + mmh3==5.1.0
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.2.0
#  + mypy-extensions==1.0.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==2.2.4
#  + oauthlib==3.2.2
#  + onnxruntime==1.21.0
#  + openai==1.69.0
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.31.1
#  + opentelemetry-exporter-otlp-proto-common==1.31.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.31.1
#  + opentelemetry-exporter-otlp-proto-http==1.31.1
#  + opentelemetry-instrumentation==0.52b1
#  + opentelemetry-instrumentation-asgi==0.52b1
#  + opentelemetry-instrumentation-fastapi==0.52b1
#  + opentelemetry-proto==1.31.1
#  + opentelemetry-sdk==1.31.1
#  + opentelemetry-semantic-conventions==0.52b1
#  + opentelemetry-util-http==0.52b1
#  + orjson==3.10.16
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parso==0.8.4
#  + pdfminer-six==20250327
#  + pdfplumber==0.11.6
#  + pexpect==4.9.0
#  + pillow==11.1.0
#  + portalocker==2.10.1
#  + posthog==3.23.0
#  + prompt-toolkit==3.0.50
#  + propcache==0.3.1
#  + protobuf==5.29.4
#  + psycopg2-binary==2.9.10
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==19.0.1
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.22
#  + pydantic==2.11.1
#  + pydantic-core==2.33.0
#  + pydantic-settings==2.8.1
#  + pygments==2.19.1
#  + pyjwt==2.10.1
#  + pypdf==5.4.0
#  + pypdfium2==4.30.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.398
#  + pysbd==0.3.4
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.0
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.13.3
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.24.0
#  + rsa==4.9
#  + schema==0.7.7
#  + setuptools==78.1.0
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.6
#  + sqlalchemy==2.0.40
#  + stack-data==0.6.3
#  + starlette==0.46.1
#  + sympy==1.13.3
#  + tabulate==0.9.0
#  + tenacity==9.0.0
#  + tiktoken==0.9.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.15.2
#  + types-requests==2.32.0.20250328
#  + typing-extensions==4.13.0
#  + typing-inspect==0.9.0
#  + typing-inspection==0.4.0
#  + tzdata==2025.2
#  + urllib3==2.3.0
#  + uv==0.6.10
#  + uvicorn==0.34.0
#  + uvloop==0.21.0
#  + watchfiles==1.0.4
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==15.0.1
#  + wrapt==1.17.2
#  + yarl==1.18.3
#  + zipp==3.21.0
#  + zstandard==0.23.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: ff853e03-43ac-4af3-9816-fdcc4b317672                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
#        Status: Executing Task...
#
# 🚀 Crew: crew
# └── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: In Progress
#
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
# 🚀 Crew: crew
# └── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: In Progress
#         └── 🧠 Thinking...
#
# 🚀 Crew: crew
# └── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: In Progress
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# - **Enhanced Contextual Understanding**: AI LLMs have significantly improved their ability to understand and generate contextually relevant text, owing to advances in training techniques and the use of larger datasets. This has led to more coherent and contextually appropriate outputs, especially in dialogue-based applications.
#
# - **Multi-modal Capabilities**: Recent developments in LLMs have integrated multi-modal learning, allowing for better comprehension and generation of content across text, audio, and visual formats. This innovation enables AI to work with various types of data inputs, resulting in richer user interactions.
#
# - **Fine-tuning Methods**: New fine-tuning approaches, including prompt engineering and few-shot learning, have enhanced the adaptability of LLMs to specific tasks without requiring extensive retraining. Organizations can customize models more quickly and economically.
#
# - **Ethical AI Considerations**: There is an ongoing emphasis on building ethical frameworks around AI LLMs to mitigate biases and ensure fair outputs. Research in this area focuses on transparency, accountability, and inclusivity to enhance public trust.
#
# - **Use in Augmented Reality**: AI LLMs are increasingly being integrated into augmented reality (AR) applications, providing real-time information and interactions in immersive environments, thus enhancing user experiences and engagement.
#
# - **Energy Efficiency**: As the demand for LLM applications grows, researchers are focusing on optimizing models for energy efficiency. Techniques such as pruning and quantization help reduce the computational power required, which is vital for sustainable AI development.
#
# - **Interactivity with Other AI Models**: The combination of LLMs with other AI technologies, such as reinforcement learning and emotional AI, is generating more sophisticated applications that can understand and mimic human emotions in language for better engagement.
#
# - **Real-time Translation**: Innovations in LLMs have led to significant advances in real-time translation services, making communication across different languages more seamless and accurate, thereby boosting international collaboration.
#
# - **Legal and Policy Frameworks**: Governments and institutions are beginning to establish legal standards and policies regarding the use of AI LLMs, emphasizing the importance of intellectual property rights, data protection, and ethical usage.
#
# - **Open Source Trends**: The trend of open-sourcing LLMs is gaining traction, allowing researchers and developers worldwide to collaborate on improvements and innovations, ultimately democratizing access to advanced AI technologies and fostering a diverse development ecosystem.
#
# These points reflect the cutting-edge developments and applications of AI LLMs as of 2024, underscoring their growing impact across various sectors and the ongoing need for responsible AI practices.
#
#
# 🚀 Crew: crew
# └── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# └── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
#        Assigned to: AI LLMs Senior Data Researcher
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 35570ffc-dc83-434e-aadc-4f9b6c97b773                                  │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 4123e85f-a1bc-40bf-8279-85561e5f6b0c
#        Status: Executing Task...
#
# 🚀 Crew: crew
# ├── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 4123e85f-a1bc-40bf-8279-85561e5f6b0c
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: In Progress
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
# 🚀 Crew: crew
# ├── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 4123e85f-a1bc-40bf-8279-85561e5f6b0c
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: In Progress
#         └── 🧠 Thinking...
#
# 🚀 Crew: crew
# ├── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 4123e85f-a1bc-40bf-8279-85561e5f6b0c
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: In Progress
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Comprehensive Report on the Developments in AI LLMs as of 2024
#
# This report explores the significant advancements in AI Large Language Models (LLMs) up to 2024, highlighting key aspects such as contextual understanding, multi-modal capabilities, ethical considerations, and more. Each section elucidates the implications and applications of these technologies across various sectors.
#
# ## Enhanced Contextual Understanding
# AI LLMs have made remarkable strides in understanding and generating contextually relevant text. Recent training techniques, along with the incorporation of expansive datasets, have contributed to this enhanced capability. These models are now better equipped to produce coherent, contextually appropriate outputs, which is especially beneficial in dialogue-based applications. This improvement facilitates smoother interactions and more meaningful engagements, as users encounter less nonsensical or irrelevant responses. As LLMs continue to evolve, their ability to maintain context over lengthy conversations and understand nuanced queries is expected to deepen, further establishing their role in customer support, mental health applications, and educational tools.
#
# ## Multi-modal Capabilities
# The integration of multi-modal learning into LLMs represents a groundbreaking advancement, enabling these models to process and generate content across various formats, including text, audio, and visual inputs. By leveraging multi-modal capabilities, AI can offer richer, more immersive user experiences. For instance, applications utilizing LLMs can now provide text-based insights alongside visuals or audio, enriching storytelling in games or enhancing learning in educational platforms. This cross-domain functionality enables novel user interactions where the AI can respond to an array of signals, adapting its outputs based on a user's engagement across mediums.
#
# ## Fine-tuning Methods
# The evolution of fine-tuning methodologies, such as prompt engineering and few-shot learning, has made it easier for organizations to customize AI LLMs for specific tasks. These advancements reduce the time and resources required for extensive retraining, allowing businesses to deploy AI solutions more flexibly and cost-effectively. This level of adaptability means that companies can quickly align LLMs with their unique operational needs, tailoring applications for customer service, content creation, and specialized industry requirements, thus driving broader adoption across various sectors.
#
# ## Ethical AI Considerations
# As AI LLMs become increasingly integrated into everyday applications, the focus on ethical frameworks has gained momentum. Stakeholders are actively researching ways to mitigate inherent biases and ensure equitable outputs. Emphasis on transparency, accountability, and inclusivity aims to enhance public trust. Organizations are beginning to adopt guidelines that enforce ethical AI practices, including thorough audits of AI decisions and inclusive datasets. These measures are vital in assuring users that AI decisions are fair and grounded, especially in sensitive domains such as hiring, finances, and law enforcement.
#
# ## Use in Augmented Reality
# The application of AI LLMs in augmented reality (AR) substantially enhances user experiences by providing real-time information and dynamic interactions within immersive environments. For instance, AI-powered AR applications can assist users in navigational tasks or educational environments, overlaying contextual information on physical objects or environments. This integration supports richer user interactions and can lead to more effective learning experiences or engaging gaming scenarios, representing a future where seamless blending of physical and digital experiences is commonplace.
#
# ## Energy Efficiency
# With the burgeoning demand for LLM applications, researchers are prioritizing energy efficiency in their designs. Techniques such as pruning and quantization are being refined to decrease the computational resources required for model execution. These advancements are essential for promoting sustainable AI development, where minimizing energy consumption aligns with global efforts to reduce carbon footprints. By investing in more energy-efficient models, organizations can ensure that they not only meet user demands but also contribute positively to environmental social governance goals.
#
# ## Interactivity with Other AI Models
# The synergy between LLMs and other AI paradigms, like reinforcement learning and emotional AI, is resulting in more complex applications capable of understanding and mimicking human emotions. This development leads to enhanced engagement in interactive applications, such as virtual companions and customer service agents that can respond empathetically to users. By combining these technologies, developers are creating systems that can better interpret user feelings, enabling more natural and effective communication, thus enhancing the overall user experience.
#
# ## Real-time Translation
# AI LLMs have driven significant progress in real-time translation capabilities, enabling instantaneous communication across diverse languages. These enhancements improve accuracy, fluency, and context-awareness, which foster better international collaboration and understanding. Companies and organizations increasingly rely on these capabilities to facilitate global business operations, conferences, and multicultural exchanges, effectively breaking down language barriers and promoting inclusivity in communication.
#
# ## Legal and Policy Frameworks
# As AI LLMs proliferate, legal standards and policies surrounding their use are being established by governments and institutions. Key aspects of these frameworks include the protection of intellectual property rights, data security, and ethical usage. Ensuring that AI technologies are developed and employed responsibly is crucial in maintaining societal trust and preventing misuse. As regulations emerge, organizations must adapt to comply with legal standards while finding ways to balance innovation with ethical considerations.
#
# ## Open Source Trends
# The trend towards open-sourcing LLMs is empowering researchers and developers globally, promoting collaboration and collective advancement in AI technologies. By allowing access to underlying algorithms and code, the open-source movement fosters a diverse development ecosystem where innovations can thrive. This approach enhances the pace of improvement in AI functionalities, democratizes access to cutting-edge technologies, and equips smaller organizations with tools to compete, ultimately driving a dynamic landscape of AI developments that benefit society as a whole.
#
# In conclusion, the advancements in AI LLMs as of 2024 are vast and impactful, spanning enhanced contextual understanding, multi-modal capabilities, and ethical considerations. The ongoing improvements not only facilitate more effective interactions but also invite critical discussions surrounding sustainability, legal implications, and collaborative development. As these trends evolve, they will undoubtedly shape the future of human-computer interaction, making AI more accessible and effective for various applications across different sectors.
#
#
# 🚀 Crew: crew
# ├── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 4123e85f-a1bc-40bf-8279-85561e5f6b0c
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# ├── 📋 Task: 35570ffc-dc83-434e-aadc-4f9b6c97b773
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 4123e85f-a1bc-40bf-8279-85561e5f6b0c
#        Assigned to: AI LLMs Reporting Analyst
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 4123e85f-a1bc-40bf-8279-85561e5f6b0c                                  │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: ff853e03-43ac-4af3-9816-fdcc4b317672                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
